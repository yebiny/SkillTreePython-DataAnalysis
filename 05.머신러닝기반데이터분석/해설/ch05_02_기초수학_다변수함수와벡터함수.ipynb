# %% [markdown]
# <a href="https://colab.research.google.com/github/yebiny/SkillTreePython-DataAnalysis/blob/main/05.%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D%EA%B8%B0%EB%B0%98%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D/%ED%95%B4%EC%84%A4/ch05_02_%EA%B8%B0%EC%B4%88%EC%88%98%ED%95%99_%EB%8B%A4%EB%B3%80%EC%88%98%ED%95%A8%EC%88%98%EC%99%80%EB%B2%A1%ED%84%B0%ED%95%A8%EC%88%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ch05.02. 기초수학 - 다변수함수와 벡터함수
# ---
# * 날짜:
# * 이름:
#
# ## 학습내용
#     - 스칼라 함수와 벡터 함수에 대해 이해한다.
#     - 일변수 함수와 다변수 함수에 대해 이해한다.
#
# ## 라이브러리 임포트
#
# ```
# import numpy as np
# import matplotlib.pyplot as plt
# plt.rcParams['font.size'] = 15
# plt.rcParams['xtick.labelsize'] = 8
# plt.rcParams['ytick.labelsize'] = 8
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 15
plt.rcParams['xtick.labelsize'] = 8
plt.rcParams['ytick.labelsize'] = 8

# %% [markdown]
# ### 일변수 스칼라 함수
# ---
#
# 하나의 인풋(=스칼라, 일변수), 하나의 아웃풋(=스칼라, 스칼라함수)
#
# \begin{align}
# y = f(x)
# \end{align}

# %% [markdown]
# #### **예제 01**
#
# \begin{align}
# f(x) = x^2+2x+1
# \end{align}

# %% [markdown]
# * 함수 생성하기

# %%
def f1(x):
  return x**2+2*x+1
f1(3)
# Out:
# 16

# %% [markdown]
# * 인풋 정의 (-10~10, 100개)

# %%
xs = np.linspace(-10,10,100)
fs = f1(xs)
xs.shape, fs.shape
# Out:
# ((100,), (100,))

# %% [markdown]
# * 2d플롯으로 시각화

# %%
fig, ax = plt.subplots(1)
ax.plot(xs, fs, alpha=.8)
ax.set_title('$f(x)$ according to $x$')
ax.set_xlabel('$x$')
ax.set_ylabel('$f(x)$')

x = -1
plt.plot(x, f1(x), marker='o', c='r')
plt.text(x, f1(x), f'({x}, {np.round(f1(x),2)})')
plt.show()

# %% [markdown]
# * 그래프 설명
#   * x가 가질수 있는 값 : 모든 실수
#   * f(x)가 가질 수 있는 값: 0 이상의 모든 실수
#   * 그래프의 특징 : x값이 -1일때 아웃풋 값이 가장 작으며, 양쪽으로 아웃풋 값은 커진다

# %% [markdown]
# #### **예제 02**
#
# \begin{align}
# f(x) = cosin(x)
# \end{align}

# %% [markdown]
# * 함수 생성하기

# %%
def f2(x):
  return np.cos(x)
f2(5)
# Out:
# 0.28366218546322625

# %% [markdown]
# * 인풋 정의 (-10~10, 100개)

# %%
xs = np.linspace(-10,10,100)
fs = f2(xs)
xs.shape, fs.shape
# Out:
# ((100,), (100,))

# %% [markdown]
# * 2d플롯으로 시각화

# %%
fig, ax = plt.subplots(1)
ax.plot(xs, fs, alpha=.8)
ax.set_title('$f(x)$ according to $x$')
ax.set_xlabel('$x$')
ax.set_ylabel('$f(x)$')

x = 0
plt.plot(x, f2(x), marker='o', c='r')
plt.text(x, f2(x), f'({x}, {np.round(f2(x),2)})')
plt.show()

# %% [markdown]
# * 그래프 설명
#   * x가 가질수 있는 값 (인풋) : 모든 실수
#   * f(x)가 가질 수 있는 값 (아웃풋) : -1과 1 사이 모든 실수
#   * 그래프의 특징 :주기적으로 -1과 1 사이를 횡보한다.

# %% [markdown]
# ### 다변수 스칼라 함수
# ---
#
# 여러개의 인풋(=다변수), 하나의 아웃풋(=스칼라, 스칼라함수)
#
#
# \begin{align}
# y = f(𝐱)\\
# \end{align}

# %% [markdown]
# #### **예제 03**
#
# \begin{align}
# f(x, y) = x+y
# \end{align}

# %% [markdown]
# * 함수 생성하기

# %%
def f3(x, y):
  return x+y 
f3(1,1)
# Out:
# 2

# %% [markdown]
# * 인풋 정의 (x, y, 모두 -15~20 값)

# %%
xs = np.linspace(-15,20,20)
ys = np.linspace(-15,20,20)
X, Y = np.meshgrid(xs,ys)
F = f3(X, Y)
X.shape, Y.shape, F.shape
# Out:
# ((20, 20), (20, 20), (20, 20))

# %% [markdown]
# * 3d플롯으로 시각화

# %%
fig = plt.figure(figsize=(9,7))
ax = plt.axes(projection='3d')
ax.scatter3D(X, Y, F, c='k', marker='.')
surf = ax.plot_surface(X, Y, F, cmap='rainbow', alpha=.7)

ax.set_title('$f(x,y)$ acording to x, y')
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.set_zlabel('$f(x,y)$')
fig.colorbar(surf, shrink=.6, label='f(x,y)')
plt.show()

# %% [markdown]
# * 그래프 설명
#   * x, y가 가질수 있는 값 (인풋) : 모든 실수
#   * f(x)가 가질 수 있는 값 (아웃풋) : 모든실수
#   * 그래프의 특징 :x, y 값이 함께 증가하는 방향으로 아웃풋 f(x) 도 커진다

# %% [markdown]
# #### **예제 04**
#
# \begin{align}
# f(x, y) = (x-5)^2+(y-5)^2
# \end{align}

# %% [markdown]
# * 함수 생성하기

# %%
def f4(x, y):
  return (x-5)**2+(y-5)**2 
f4(2,2)
# Out:
# 18

# %% [markdown]
# * 인풋 정의(x, y 모두 -15~20 사이 값)

# %%
xs = np.linspace(-15,20,20)
ys = np.linspace(-15,20,20)
X, Y = np.meshgrid(xs,ys)
F = f4(X,Y)
X.shape, Y.shape, F.shape
# Out:
# ((20, 20), (20, 20), (20, 20))

# %% [markdown]
# * 3d플롯으로 시각화

# %%
fig = plt.figure(figsize=(10,7))
ax = plt.axes(projection='3d')
ax.scatter3D(X, Y, F, c='k', marker='.')
surf = ax.plot_surface(X, Y, F, cmap='rainbow', alpha=.5)

ax.set_title('f(x,y) acording to x, y')
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.set_zlabel('$f(x,y)$')
fig.colorbar(surf, shrink=.6, label='f(x,y)')
plt.show()

# %% [markdown]
# * 그래프 설명
#   * x, y가 가질수 있는 값 (인풋) : 모든 실수
#   * f(x)가 가질 수 있는 값 (아웃풋) : 0보다 큰 모든 실수
#   * 그래프의 특징 : x=5, y=5 일때 최소값을 가지고 이 값에서 멀어질수록 아웃풋 f(x) 도 커진다

# %% [markdown]
# #### **예제 05**
#
# \begin{align}
# f(x_1, x_2) = 50(x_2-x_1^2)^2+(2-x_1)^2
# \end{align}

# %% [markdown]
# * 함수 생성하기

# %%
def f5(x1, x2):
  return 50*(x2-(x1**2))**2 + (2-x1)**2
f5(2,4)
# Out:
# 0

# %% [markdown]
# * 인풋 정의 (x: -2 ~ 2 20개, y: -1~3 20개)

# %%
xs1 = np.linspace(-2, 2, 20)
xs2 = np.linspace(-1, 3, 20)
X1, X2 = np.meshgrid(xs1,xs2)
F = f5(X1, X2)
X1.shape, X2.shape, F.shape
# Out:
# ((20, 20), (20, 20), (20, 20))

# %% [markdown]
# * 3d플롯으로 시각화

# %%
fig = plt.figure(figsize=(10,7))
ax = plt.axes(projection='3d')
ax.scatter3D(X1, X2, F, c='k', marker='.')
surf = ax.plot_surface(X1, X2, F, cmap='rainbow', alpha=.5)

ax.set_title('$f(x_1, x_2)$ acording to $x_1$ and $x_2$')
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_zlabel('$f(x_1,x_2)$')
fig.colorbar(surf, shrink=.6, label='$f(x_1, x_2)$')
plt.show()

# %% [markdown]
# * $x_1$, $x_2$의 범위를 둘다 -4부터 4로 변경하여 다시 그려보세요.

# %%
xs1 = np.linspace(-4, 4, 20)
xs2 = np.linspace(-4, 4, 20)
X1, X2 = np.meshgrid(xs1,xs2)
F = f5(X1, X2)
X1.shape, X2.shape, F.shape

fig = plt.figure(figsize=(10,7))
ax = plt.axes(projection='3d')
ax.scatter3D(X1, X2, F, c='k', marker='.')
surf = ax.plot_surface(X1, X2, F, cmap='rainbow', alpha=.5)

ax.set_title('$f(x_1, x_2)$ acording to $x_1$ and $x_2$')
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_zlabel('$f(x_1,x_2)$')
fig.colorbar(surf, shrink=.6, label='$f(x_1, x_2)$')
plt.show()

# %% [markdown]
# * 그래프 설명
#   * x, y가 가질수 있는 값 (인풋) : 모든 실수
#   * f(x)가 가질 수 있는 값 (아웃풋) : 0보다 큰 모든 실수
#   * 그래프의 특징 : x1=2, x2=4 일때 최소값 0을 가진다. x2의 변화보다 x1의 변화가 아웃풋 값에 큰 영향을 미친다. (x1의 제곱 함수기 때문에)

# %% [markdown]
# ## 일변수 벡터함수
# ---
#
# 하나의 인풋(=스칼라, 일변수), 여러개의 아웃풋(=스칼라, 스칼라함수)
#
#
#
#
# \begin{align}
# f(x) = (f_1(x), f_2(x), ..., f_n(x))^T
# \end{align}

# %% [markdown]
# #### **예제 06**
#
# \begin{align}
# f(x) = \begin{pmatrix}
# h(x)\\
# g(x)\\
# \end{pmatrix}  = \begin{pmatrix}
# x^2\\
# 5x\\
# \end{pmatrix}
# \end{align}

# %% [markdown]
# * 함수 $f(x)$ 생성하기

# %%
def f6(x):
  g = 5*x
  h = x**2
  return   np.array([g, h])

f6(5)
# Out:
# array([25, 25])

# %% [markdown]
# * 인풋 정의 (-10~10 20개)

# %%
xs = np.linspace(-10,10,20)
gs, hs = f6(xs)
xs.shape, gs.shape, hs.shape
# Out:
# ((20,), (20,), (20,))

# %% [markdown]
# * 2d플롯으로 시각화

# %%
fig, ax = plt.subplots(1)

ax.plot(gs, hs)
ax.set_title('$f(x)$ space')
ax.set_xlabel('$g(x)$')
ax.set_ylabel('$h(x)$')

scat = ax.scatter(gs, hs, c=xs, cmap='rainbow')
fig.colorbar(scat)
plt.show()

# %% [markdown]
# * 그래프 설명
#   * x가 가질수 있는 값 (인풋) : 모든 실수
#   * g(x)가 가질 수 있는 값 (첫번째 아웃풋) : 모든 실수
#   * h(x)가 가질수 있는 값 (두번째 아웃풋): 0보다 큰 모든 실수

# %% [markdown]
# #### **예제 07**
#
# \begin{align}
# f(t) = \begin{pmatrix}
# x(t)\\
# y(t)\\
# z(t)\\ \end{pmatrix} = \begin{pmatrix}
# sin(6t)\\
# \frac{t}{4}\\
# \frac{t^2}{2}\\
# \end{pmatrix}
# \end{align}

# %% [markdown]
# * 함수 생성하기

# %%
def f7(t):
  x = np.sin(6*t)
  y = 1/4*t
  z = t**2/2
  np.array([x, y, z])
  return   np.array([x, y, z])
f7(3)
# Out:
# array([-0.75098725,  0.75      ,  4.5       ])

# %% [markdown]
# * 인풋 정의 (-1~3 200개)

# %%
ts = np.linspace(-1,3,200)
xs, ys, zs = f7(ts)

ts.shape, xs.shape, ys.shape, zs.shape
# Out:
# ((200,), (200,), (200,), (200,))

# %% [markdown]
# * 3d플롯으로 시각화

# %%
fig = plt.figure(figsize=(10,7))
ax = plt.axes(projection='3d')
scat = ax.scatter3D(xs, ys, zs, c=ts, marker='o', cmap='rainbow')

ax.set_title('$f(t)$ space')
ax.set_xlabel('$x(t)$')
ax.set_ylabel('$y(t)$')
ax.set_zlabel('$z(t)$')
fig.colorbar(scat, shrink=.6, label='t')
plt.show()

# %% [markdown]
# * 그래프 설명
#   * t가 가질수 있는 값 (인풋) : 모든 실수
#   * x(t)가 가질 수 있는 값 (첫번째 아웃풋) : -1과 1 사이 수
#   * y(t)가 가질 수 있는 값 (두번째 아웃풋) : 모든 실수
#   * z(t)가 가질 수 있는 값 (세번째 아웃풋) : 0보다 큰 모든 실수

# %% [markdown]
# #### **예제 08**
#
# \begin{align}
# \tau(t) = \begin{pmatrix}
# x(t)\\
# y(t)\\
# z(t)\\ \end{pmatrix} = \begin{pmatrix}
# cos(t)\\
# sin(t)\\
# t\\
# \end{pmatrix}
# \end{align}

# %% [markdown]
# * 함수 생성하기

# %%
def f8(t):
  return np.array([np.cos(t), np.sin(t), t])
f8(3)
# Out:
# array([-0.9899925 ,  0.14112001,  3.        ])

# %% [markdown]
# * 인풋 정의(-10 ~ 10 사이 200개)

# %%
ts = np.linspace(-10,10,200)
xs, ys, zs = f8(ts)

ts.shape, xs.shape, ys.shape, zs.shape
# Out:
# ((200,), (200,), (200,), (200,))

# %% [markdown]
# * 3d플롯으로 시각화

# %%
fig = plt.figure(figsize=(10,7))
ax = plt.axes(projection='3d')
scat = ax.scatter3D(xs, ys, zs, c=ts, marker='.', cmap='rainbow')

ax.set_title('$f(t)$ space')
ax.set_xlabel('$cos(t)$')
ax.set_ylabel('$sin(t)$')
ax.set_zlabel('$t$')
fig.colorbar(scat, shrink=.6, label='t')
plt.show()

# %% [markdown]
# * 그래프 설명
#   * t가 가질수 있는 값 (인풋) : 모든 실수
#   * cos(t)가 가질 수 있는 값 (첫번째 아웃풋) : -1과 1 사이 수
#   * sing(t)가 가질 수 있는 값 (두번째 아웃풋) : -1과 1사이 수

# %% [markdown]
# ## 다변수 벡터함수
# ---
# 여러개의 인풋(=스칼라, 일변수), 여러개의 아웃풋(=스칼라, 스칼라함수)
#
# \begin{align}
# f(𝐱) = (f_1(𝐱), f_2(𝐱), ..., f_n(𝐱))^T
# \end{align}

# %% [markdown]
# #### **예제 09**
#
#
# \begin{align}
# f(x,y) = \begin{pmatrix}
# x^2\\
# y^2\\
# xy\\ \end{pmatrix}
# \end{align}

# %% [markdown]
# * 함수 생성하기

# %%
def f9(x, y):
  return np.array([x**2, y**2, x*y])
f9(1, 2)

# %% [markdown]
# * 인풋 정의 (x,y 모두 -0.5 ~ 1 사이 50개)

# %%
xs = np.linspace(-.5,1,50)
ys = np.linspace(-.5,1,50)
X, Y = np.meshgrid(xs, ys)
Fs = f9(X, Y)
X.shape, Y.shape, Fs.shape
# Out:
# ((50, 50), (50, 50), (3, 50, 50))

# %% [markdown]
# * 3d플롯으로 시각화

# %%
fig = plt.figure(figsize=(10,7))

ax = plt.axes(projection='3d')
ax.scatter3D(Fs[0], Fs[1], Fs[2], marker='.')

ax.set_title('$f(x,y)$ space')
ax.set_xlabel('$x^2$')
ax.set_ylabel('$y^2$')
ax.set_zlabel('$xy$')
plt.show()

# %% [markdown]
# #### **예제 10**
#
#
# \begin{align}
# f(u,v) = \begin{pmatrix}
# u\\
# v\\
# 1+u^2+\frac{v}{1+v^2}\\ \end{pmatrix}, \ \ \ \ \ 0 \leq u, v \leq1
# \end{align}

# %% [markdown]
# * 함수 생성하기

# %%
def f10(u, v):
  return np.array([u, v, 1+u**2+v/(1+v**2)])
f10(1,2)
# Out:
# array([1. , 2. , 2.4])

# %% [markdown]
# * 인풋 정의 (u, v 모두 0 ~ 1 사이 50개)

# %%
us = np.linspace(0,1,50)
vs = np.linspace(0,1,50)
U, V = np.meshgrid(us, vs)
F = f10(U, V)
U.shape, V.shape, F.shape
# Out:
# ((50, 50), (50, 50), (3, 50, 50))

# %% [markdown]
# * 3d플롯으로 시각화

# %%
fig = plt.figure(figsize=(9,9))

ax = plt.axes(projection='3d')
ax.scatter3D(F[0], F[1], F[2], marker='.')

ax.set_title('$f(u,v)$ space')
ax.set_xlabel('$u$')
ax.set_ylabel('$v$')
ax.set_zlabel('$1+u^2+v/(1+v^2)$')
plt.show()
